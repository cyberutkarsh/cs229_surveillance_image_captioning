# %%
#!pip3 install --upgrade tensorflow-gpu

# %%
# !pwd
# Out:
# /mnt/batch/tasks/shared/LS_root/mounts/clusters/ml-compute-4-gpu/code/Users/utkarsh/CLIP_prefix_caption

# %%
# !python parse_coco.py --clip_model_type ViT-B/32
# Out:
# 350 captions loaded from json
# 100%|█████████████████████████████████████████| 350/350 [00:43<00:00,  8.06it/s]
# Done
# 350 embeddings saved

# %%
# !python train.py --data ./data/coco/oscar_split_ViT-B_32_train.pkl --out_dir ./coco_train/ --epochs 200
# Out:
# 2022-11-15 00:17:40.615576: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-11-15 00:17:40.615620: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# /anaconda/envs/azureml_py36/lib/python3.6/site-packages/ray/autoscaler/_private/cli_logger.py:61: FutureWarning: Not all Ray CLI dependencies were found. In Ray 1.4+, the Ray CLI, autoscaler, and dashboard will only be usable via `pip install 'ray[default]'`. Please update your install command.
#   "update your install command.", FutureWarning)
# Failure while loading azureml_run_type_providers. Failed to load entrypoint automl = azureml.train.automl.run:AutoMLRun._from_run_dto with exception (pyarrow 6.0.1 (/home/azureuser/.local/lib/python3.6/site-packages), Requirement.parse('pyarrow<4.0.0,>=0.17.0'), {'azureml-dataset-runtime'}).
# Data size is 350
# Train both prefix and GPT
# >>> Training epoch 0
# coco_prefix: 100%|██████████████████████| 8/8 [00:11<00:00,  1.39s/it, loss=5.6]
# >>> Training epoch 1
# coco_prefix: 100%|█████████████████████| 8/8 [00:11<00:00,  1.40s/it, loss=5.52]
# >>> Training epoch 2
# coco_prefix: 100%|█████████████████████| 8/8 [00:11<00:00,  1.39s/it, loss=5.58]
# >>> Training epoch 3
# coco_prefix: 100%|█████████████████████| 8/8 [00:11<00:00,  1.39s/it, loss=5.42]
# >>> Training epoch 4
# coco_prefix: 100%|█████████████████████| 8/8 [00:11<00:00,  1.39s/it, loss=5.64]
# >>> Training epoch 5
# coco_prefix: 100%|█████████████████████| 8/8 [00:11<00:00,  1.39s/it, loss=5.39]
# >>> Training epoch 6
# coco_prefix: 100%|█████████████████████| 8/8 [00:11<00:00,  1.39s/it, loss=5.36]
# >>> Training epoch 7
# coco_prefix: 100%|█████████████████████| 8/8 [00:11<00:00,  1.40s/it, loss=5.12]
# >>> Training epoch 8
# coco_prefix: 100%|█████████████████████| 8/8 [00:11<00:00,  1.39s/it, loss=5.23]
# >>> Training epoch 9
# coco_prefix: 100%|█████████████████████| 8/8 [00:11<00:00,  1.39s/it, loss=5.13]
# >>> Training epoch 10
# coco_prefix: 100%|█████████████████████| 8/8 [00:11<00:00,  1.41s/it, loss=4.81]
# >>> Training epoch 11
# coco_prefix: 100%|█████████████████████| 8/8 [00:11<00:00,  1.40s/it, loss=5.05]
# >>> Training epoch 12
# coco_prefix: 100%|█████████████████████| 8/8 [00:11<00:00,  1.40s/it, loss=4.57]
# >>> Training epoch 13
# coco_prefix: 100%|█████████████████████| 8/8 [00:11<00:00,  1.41s/it, loss=4.61]
# >>> Training epoch 14
# coco_prefix: 100%|█████████████████████| 8/8 [00:11<00:00,  1.41s/it, loss=4.34]
# >>> Training epoch 15
# coco_prefix: 100%|█████████████████████| 8/8 [00:11<00:00,  1.40s/it, loss=4.44]
# >>> Training epoch 16
# coco_prefix: 100%|█████████████████████| 8/8 [00:11<00:00,  1.40s/it, loss=4.43]
# >>> Training epoch 17
# coco_prefix: 100%|█████████████████████| 8/8 [00:11<00:00,  1.40s/it, loss=4.39]
# >>> Training epoch 18
# coco_prefix: 100%|█████████████████████| 8/8 [00:11<00:00,  1.40s/it, loss=4.08]
# >>> Training epoch 19
# coco_prefix: 100%|█████████████████████| 8/8 [00:11<00:00,  1.42s/it, loss=3.73]
# >>> Training epoch 20
# coco_prefix: 100%|█████████████████████| 8/8 [00:11<00:00,  1.40s/it, loss=4.19]
# >>> Training epoch 21
# coco_prefix: 100%|█████████████████████| 8/8 [00:11<00:00,  1.40s/it, loss=4.09]
# >>> Training epoch 22
# coco_prefix: 100%|█████████████████████| 8/8 [00:11<00:00,  1.42s/it, loss=3.66]
# >>> Training epoch 23
# coco_prefix: 100%|██████████████████████| 8/8 [00:11<00:00,  1.41s/it, loss=3.7]
# >>> Training epoch 24
# coco_prefix: 100%|█████████████████████| 8/8 [00:11<00:00,  1.41s/it, loss=3.72]
# >>> Training epoch 25
# coco_prefix: 100%|█████████████████████| 8/8 [00:11<00:00,  1.42s/it, loss=3.79]
# >>> Training epoch 26
# coco_prefix: 100%|█████████████████████| 8/8 [00:11<00:00,  1.41s/it, loss=3.42]
# >>> Training epoch 27
# coco_prefix: 100%|█████████████████████| 8/8 [00:11<00:00,  1.41s/it, loss=3.42]
# >>> Training epoch 28
# coco_prefix: 100%|█████████████████████| 8/8 [00:11<00:00,  1.42s/it, loss=3.29]
# >>> Training epoch 29
# coco_prefix: 100%|█████████████████████| 8/8 [00:11<00:00,  1.41s/it, loss=3.23]
# >>> Training epoch 30
# coco_prefix: 100%|█████████████████████| 8/8 [00:11<00:00,  1.41s/it, loss=3.24]
# >>> Training epoch 31
# coco_prefix: 100%|█████████████████████| 8/8 [00:11<00:00,  1.41s/it, loss=3.21]
# >>> Training epoch 32
# coco_prefix: 100%|█████████████████████| 8/8 [00:11<00:00,  1.41s/it, loss=3.13]
# >>> Training epoch 33
# coco_prefix: 100%|█████████████████████| 8/8 [00:11<00:00,  1.41s/it, loss=2.97]
# >>> Training epoch 34
# coco_prefix: 100%|█████████████████████| 8/8 [00:11<00:00,  1.42s/it, loss=3.12]
# >>> Training epoch 35
# coco_prefix: 100%|█████████████████████| 8/8 [00:11<00:00,  1.41s/it, loss=3.06]
# >>> Training epoch 36
# coco_prefix: 100%|█████████████████████| 8/8 [00:11<00:00,  1.41s/it, loss=2.95]
# >>> Training epoch 37
# coco_prefix: 100%|█████████████████████| 8/8 [00:11<00:00,  1.43s/it, loss=3.14]
# >>> Training epoch 38
# coco_prefix: 100%|████████████████████████| 8/8 [00:11<00:00,  1.41s/it, loss=3]
# >>> Training epoch 39
# coco_prefix: 100%|█████████████████████| 8/8 [00:11<00:00,  1.41s/it, loss=3.18]
# >>> Training epoch 40
# coco_prefix: 100%|█████████████████████| 8/8 [00:11<00:00,  1.42s/it, loss=2.68]
# >>> Training epoch 41
# coco_prefix: 100%|█████████████████████| 8/8 [00:11<00:00,  1.41s/it, loss=2.76]
# >>> Training epoch 42
# coco_prefix: 100%|█████████████████████| 8/8 [00:11<00:00,  1.41s/it, loss=2.81]
# >>> Training epoch 43
# coco_prefix: 100%|█████████████████████| 8/8 [00:11<00:00,  1.42s/it, loss=2.82]
# >>> Training epoch 44
# coco_prefix: 100%|█████████████████████| 8/8 [00:11<00:00,  1.41s/it, loss=2.78]
# >>> Training epoch 45
# coco_prefix: 100%|██████████████████████| 8/8 [00:11<00:00,  1.41s/it, loss=2.7]
# >>> Training epoch 46
# coco_prefix: 100%|█████████████████████| 8/8 [00:11<00:00,  1.42s/it, loss=2.63]
# >>> Training epoch 47
# coco_prefix: 100%|█████████████████████| 8/8 [00:11<00:00,  1.42s/it, loss=2.73]
# >>> Training epoch 48
# coco_prefix: 100%|█████████████████████| 8/8 [00:11<00:00,  1.41s/it, loss=2.66]
# >>> Training epoch 49
# coco_prefix: 100%|█████████████████████| 8/8 [00:11<00:00,  1.43s/it, loss=2.67]
# >>> Training epoch 50
# coco_prefix: 100%|█████████████████████| 8/8 [00:11<00:00,  1.41s/it, loss=2.64]
# >>> Training epoch 51
# coco_prefix: 100%|█████████████████████| 8/8 [00:11<00:00,  1.41s/it, loss=2.63]
# >>> Training epoch 52
# coco_prefix: 100%|█████████████████████| 8/8 [00:11<00:00,  1.43s/it, loss=2.47]
# >>> Training epoch 53
# coco_prefix: 100%|█████████████████████| 8/8 [00:11<00:00,  1.41s/it, loss=2.46]
# >>> Training epoch 54
# coco_prefix: 100%|█████████████████████| 8/8 [00:11<00:00,  1.41s/it, loss=2.48]
# >>> Training epoch 55
# coco_prefix: 100%|█████████████████████| 8/8 [00:11<00:00,  1.43s/it, loss=2.43]
# >>> Training epoch 56
# coco_prefix: 100%|█████████████████████| 8/8 [00:11<00:00,  1.41s/it, loss=2.57]
# >>> Training epoch 57
# coco_prefix: 100%|█████████████████████| 8/8 [00:11<00:00,  1.42s/it, loss=2.37]
# >>> Training epoch 58
# coco_prefix: 100%|█████████████████████| 8/8 [00:11<00:00,  1.42s/it, loss=2.57]
# >>> Training epoch 59
# coco_prefix: 100%|█████████████████████| 8/8 [00:11<00:00,  1.42s/it, loss=2.54]
# >>> Training epoch 60
# coco_prefix: 100%|█████████████████████| 8/8 [00:11<00:00,  1.41s/it, loss=2.52]
# >>> Training epoch 61
# coco_prefix: 100%|█████████████████████| 8/8 [00:11<00:00,  1.41s/it, loss=2.38]
# >>> Training epoch 62
# coco_prefix: 100%|█████████████████████| 8/8 [00:11<00:00,  1.41s/it, loss=2.48]
# >>> Training epoch 63
# coco_prefix: 100%|██████████████████████| 8/8 [00:11<00:00,  1.41s/it, loss=2.5]
# >>> Training epoch 64
# coco_prefix: 100%|█████████████████████| 8/8 [00:11<00:00,  1.42s/it, loss=2.19]
# >>> Training epoch 65
# coco_prefix: 100%|█████████████████████| 8/8 [00:11<00:00,  1.42s/it, loss=2.29]
# >>> Training epoch 66
# coco_prefix: 100%|█████████████████████| 8/8 [00:11<00:00,  1.41s/it, loss=2.43]
# >>> Training epoch 67
# coco_prefix: 100%|█████████████████████| 8/8 [00:11<00:00,  1.43s/it, loss=2.24]
# >>> Training epoch 68
# coco_prefix: 100%|█████████████████████| 8/8 [00:11<00:00,  1.41s/it, loss=2.43]
# >>> Training epoch 69
# coco_prefix: 100%|██████████████████████| 8/8 [00:11<00:00,  1.41s/it, loss=2.3]
# >>> Training epoch 70
# coco_prefix: 100%|█████████████████████| 8/8 [00:11<00:00,  1.43s/it, loss=2.12]
# >>> Training epoch 71
# coco_prefix: 100%|█████████████████████| 8/8 [00:11<00:00,  1.41s/it, loss=2.44]
# >>> Training epoch 72
# coco_prefix: 100%|█████████████████████| 8/8 [00:11<00:00,  1.41s/it, loss=2.22]
# >>> Training epoch 73
# coco_prefix: 100%|█████████████████████| 8/8 [00:11<00:00,  1.43s/it, loss=2.26]
# >>> Training epoch 74
# coco_prefix: 100%|█████████████████████| 8/8 [00:11<00:00,  1.41s/it, loss=2.31]
# >>> Training epoch 75
# coco_prefix: 100%|█████████████████████| 8/8 [00:11<00:00,  1.41s/it, loss=2.21]
# >>> Training epoch 76
# coco_prefix: 100%|█████████████████████| 8/8 [00:11<00:00,  1.42s/it, loss=2.25]
# >>> Training epoch 77
# coco_prefix: 100%|█████████████████████| 8/8 [00:11<00:00,  1.41s/it, loss=2.26]
# >>> Training epoch 78
# coco_prefix: 100%|█████████████████████| 8/8 [00:11<00:00,  1.41s/it, loss=2.23]
# >>> Training epoch 79
# coco_prefix: 100%|█████████████████████| 8/8 [00:11<00:00,  1.42s/it, loss=2.26]
# >>> Training epoch 80
# coco_prefix: 100%|█████████████████████| 8/8 [00:11<00:00,  1.41s/it, loss=2.11]
# >>> Training epoch 81
# coco_prefix: 100%|█████████████████████| 8/8 [00:11<00:00,  1.42s/it, loss=2.29]
# >>> Training epoch 82
# coco_prefix: 100%|█████████████████████| 8/8 [00:11<00:00,  1.43s/it, loss=2.25]
# >>> Training epoch 83
# coco_prefix: 100%|█████████████████████| 8/8 [00:11<00:00,  1.41s/it, loss=2.08]
# >>> Training epoch 84
# coco_prefix: 100%|█████████████████████| 8/8 [00:11<00:00,  1.41s/it, loss=2.33]
# >>> Training epoch 85
# coco_prefix: 100%|█████████████████████| 8/8 [00:11<00:00,  1.42s/it, loss=2.38]
# >>> Training epoch 86
# coco_prefix: 100%|█████████████████████| 8/8 [00:11<00:00,  1.41s/it, loss=2.27]
# >>> Training epoch 87
# coco_prefix: 100%|█████████████████████| 8/8 [00:11<00:00,  1.42s/it, loss=2.23]
# >>> Training epoch 88
# coco_prefix: 100%|█████████████████████| 8/8 [00:11<00:00,  1.43s/it, loss=2.27]
# >>> Training epoch 89
# coco_prefix: 100%|█████████████████████| 8/8 [00:11<00:00,  1.41s/it, loss=2.02]
# >>> Training epoch 90
# coco_prefix: 100%|█████████████████████| 8/8 [00:11<00:00,  1.41s/it, loss=2.24]
# >>> Training epoch 91
# coco_prefix: 100%|████████████████████████| 8/8 [00:11<00:00,  1.42s/it, loss=2]
# >>> Training epoch 92
# coco_prefix: 100%|█████████████████████| 8/8 [00:11<00:00,  1.41s/it, loss=2.01]
# >>> Training epoch 93
# coco_prefix: 100%|█████████████████████| 8/8 [00:11<00:00,  1.41s/it, loss=2.02]
# >>> Training epoch 94
# coco_prefix: 100%|█████████████████████| 8/8 [00:11<00:00,  1.44s/it, loss=2.08]
# >>> Training epoch 95
# coco_prefix: 100%|█████████████████████| 8/8 [00:11<00:00,  1.41s/it, loss=2.09]
# >>> Training epoch 96
# coco_prefix: 100%|█████████████████████| 8/8 [00:11<00:00,  1.42s/it, loss=2.04]
# >>> Training epoch 97
# coco_prefix: 100%|█████████████████████| 8/8 [00:11<00:00,  1.43s/it, loss=1.96]
# >>> Training epoch 98
# coco_prefix: 100%|█████████████████████| 8/8 [00:11<00:00,  1.41s/it, loss=1.91]
# >>> Training epoch 99
# coco_prefix: 100%|█████████████████████| 8/8 [00:11<00:00,  1.42s/it, loss=2.03]
# >>> Training epoch 100
# coco_prefix: 100%|█████████████████████| 8/8 [00:11<00:00,  1.43s/it, loss=2.05]
# >>> Training epoch 101
# coco_prefix: 100%|█████████████████████| 8/8 [00:11<00:00,  1.41s/it, loss=2.15]
# >>> Training epoch 102
# coco_prefix: 100%|█████████████████████| 8/8 [00:11<00:00,  1.42s/it, loss=1.93]
# >>> Training epoch 103
# coco_prefix: 100%|█████████████████████| 8/8 [00:11<00:00,  1.41s/it, loss=2.02]
# >>> Training epoch 104
# coco_prefix: 100%|█████████████████████| 8/8 [00:11<00:00,  1.41s/it, loss=1.98]
# >>> Training epoch 105
# coco_prefix: 100%|█████████████████████| 8/8 [00:11<00:00,  1.42s/it, loss=1.98]
# >>> Training epoch 106
# coco_prefix: 100%|█████████████████████| 8/8 [00:11<00:00,  1.41s/it, loss=1.74]
# >>> Training epoch 107
# coco_prefix: 100%|█████████████████████| 8/8 [00:11<00:00,  1.41s/it, loss=1.68]
# >>> Training epoch 108
# coco_prefix: 100%|█████████████████████| 8/8 [00:11<00:00,  1.43s/it, loss=1.86]
# >>> Training epoch 109
# coco_prefix: 100%|█████████████████████| 8/8 [00:11<00:00,  1.41s/it, loss=1.91]
# >>> Training epoch 110
# coco_prefix: 100%|█████████████████████| 8/8 [00:11<00:00,  1.41s/it, loss=1.91]
# >>> Training epoch 111
# coco_prefix: 100%|██████████████████████| 8/8 [00:11<00:00,  1.42s/it, loss=1.8]
# >>> Training epoch 112
# coco_prefix: 100%|█████████████████████| 8/8 [00:11<00:00,  1.42s/it, loss=1.89]
# >>> Training epoch 113
# coco_prefix: 100%|█████████████████████| 8/8 [00:11<00:00,  1.41s/it, loss=2.03]
# >>> Training epoch 114
# coco_prefix: 100%|█████████████████████| 8/8 [00:11<00:00,  1.41s/it, loss=1.77]
# >>> Training epoch 115
# coco_prefix: 100%|█████████████████████| 8/8 [00:11<00:00,  1.41s/it, loss=1.94]
# >>> Training epoch 116
# coco_prefix: 100%|█████████████████████| 8/8 [00:11<00:00,  1.41s/it, loss=1.75]
# >>> Training epoch 117
# coco_prefix: 100%|█████████████████████| 8/8 [00:11<00:00,  1.43s/it, loss=1.77]
# >>> Training epoch 118
# coco_prefix: 100%|█████████████████████| 8/8 [00:11<00:00,  1.41s/it, loss=1.82]
# >>> Training epoch 119
# coco_prefix: 100%|█████████████████████| 8/8 [00:11<00:00,  1.41s/it, loss=1.66]
# >>> Training epoch 120
# coco_prefix: 100%|█████████████████████| 8/8 [00:11<00:00,  1.43s/it, loss=1.79]
# >>> Training epoch 121
# coco_prefix: 100%|█████████████████████| 8/8 [00:11<00:00,  1.42s/it, loss=1.71]
# >>> Training epoch 122
# coco_prefix: 100%|█████████████████████| 8/8 [00:11<00:00,  1.41s/it, loss=1.84]
# >>> Training epoch 123
# coco_prefix: 100%|█████████████████████| 8/8 [00:11<00:00,  1.42s/it, loss=1.81]
# >>> Training epoch 124
# coco_prefix: 100%|█████████████████████| 8/8 [00:11<00:00,  1.42s/it, loss=1.68]
# >>> Training epoch 125
# coco_prefix: 100%|█████████████████████| 8/8 [00:11<00:00,  1.41s/it, loss=1.53]
# >>> Training epoch 126
# coco_prefix: 100%|█████████████████████| 8/8 [00:11<00:00,  1.42s/it, loss=1.59]
# >>> Training epoch 127
# coco_prefix: 100%|█████████████████████| 8/8 [00:11<00:00,  1.41s/it, loss=1.62]
# >>> Training epoch 128
# coco_prefix: 100%|█████████████████████| 8/8 [00:11<00:00,  1.41s/it, loss=1.71]
# >>> Training epoch 129
# coco_prefix: 100%|██████████████████████| 8/8 [00:11<00:00,  1.42s/it, loss=1.5]
# >>> Training epoch 130
# coco_prefix: 100%|██████████████████████| 8/8 [00:11<00:00,  1.41s/it, loss=1.7]
# >>> Training epoch 131
# coco_prefix: 100%|█████████████████████| 8/8 [00:11<00:00,  1.41s/it, loss=1.51]
# >>> Training epoch 132
# coco_prefix: 100%|█████████████████████| 8/8 [00:11<00:00,  1.43s/it, loss=1.66]
# >>> Training epoch 133
# coco_prefix: 100%|█████████████████████| 8/8 [00:11<00:00,  1.41s/it, loss=1.54]
# >>> Training epoch 134
# coco_prefix: 100%|█████████████████████| 8/8 [00:11<00:00,  1.41s/it, loss=1.51]
# >>> Training epoch 135
# coco_prefix: 100%|█████████████████████| 8/8 [00:11<00:00,  1.42s/it, loss=1.62]
# >>> Training epoch 136
# coco_prefix: 100%|█████████████████████| 8/8 [00:11<00:00,  1.41s/it, loss=1.61]
# >>> Training epoch 137
# coco_prefix: 100%|█████████████████████| 8/8 [00:11<00:00,  1.41s/it, loss=1.59]
# >>> Training epoch 138
# coco_prefix: 100%|█████████████████████| 8/8 [00:11<00:00,  1.43s/it, loss=1.63]
# >>> Training epoch 139
# coco_prefix: 100%|█████████████████████| 8/8 [00:11<00:00,  1.41s/it, loss=1.47]
# >>> Training epoch 140
# coco_prefix: 100%|█████████████████████| 8/8 [00:11<00:00,  1.41s/it, loss=1.56]
# >>> Training epoch 141
# coco_prefix: 100%|█████████████████████| 8/8 [00:11<00:00,  1.43s/it, loss=1.53]
# >>> Training epoch 142
# coco_prefix: 100%|█████████████████████| 8/8 [00:11<00:00,  1.41s/it, loss=1.55]
# >>> Training epoch 143
# coco_prefix: 100%|█████████████████████| 8/8 [00:11<00:00,  1.41s/it, loss=1.53]
# >>> Training epoch 144
# coco_prefix: 100%|█████████████████████| 8/8 [00:11<00:00,  1.42s/it, loss=1.55]
# >>> Training epoch 145
# coco_prefix: 100%|█████████████████████| 8/8 [00:11<00:00,  1.41s/it, loss=1.56]
# >>> Training epoch 146
# coco_prefix: 100%|█████████████████████| 8/8 [00:11<00:00,  1.41s/it, loss=1.51]
# >>> Training epoch 147
# coco_prefix: 100%|█████████████████████| 8/8 [00:11<00:00,  1.43s/it, loss=1.48]
# >>> Training epoch 148
# coco_prefix: 100%|█████████████████████| 8/8 [00:11<00:00,  1.41s/it, loss=1.37]
# >>> Training epoch 149
# coco_prefix: 100%|█████████████████████| 8/8 [00:11<00:00,  1.41s/it, loss=1.36]
# >>> Training epoch 150
# coco_prefix: 100%|█████████████████████| 8/8 [00:11<00:00,  1.43s/it, loss=1.42]
# >>> Training epoch 151
# coco_prefix: 100%|██████████████████████| 8/8 [00:11<00:00,  1.41s/it, loss=1.4]
# >>> Training epoch 152
# coco_prefix: 100%|█████████████████████| 8/8 [00:11<00:00,  1.41s/it, loss=1.44]
# >>> Training epoch 153
# coco_prefix: 100%|█████████████████████| 8/8 [00:11<00:00,  1.43s/it, loss=1.25]
# >>> Training epoch 154
# coco_prefix: 100%|█████████████████████| 8/8 [00:11<00:00,  1.41s/it, loss=1.32]
# >>> Training epoch 155
# coco_prefix: 100%|█████████████████████| 8/8 [00:11<00:00,  1.41s/it, loss=1.23]
# >>> Training epoch 156
# coco_prefix: 100%|█████████████████████| 8/8 [00:11<00:00,  1.42s/it, loss=1.41]
# >>> Training epoch 157
# coco_prefix: 100%|█████████████████████| 8/8 [00:11<00:00,  1.41s/it, loss=1.37]
# >>> Training epoch 158
# coco_prefix: 100%|█████████████████████| 8/8 [00:11<00:00,  1.41s/it, loss=1.27]
# >>> Training epoch 159
# coco_prefix: 100%|█████████████████████| 8/8 [00:11<00:00,  1.43s/it, loss=1.31]
# >>> Training epoch 160
# coco_prefix: 100%|█████████████████████| 8/8 [00:11<00:00,  1.41s/it, loss=1.22]
# >>> Training epoch 161
# coco_prefix: 100%|█████████████████████| 8/8 [00:11<00:00,  1.41s/it, loss=1.23]
# >>> Training epoch 162
# coco_prefix: 100%|█████████████████████| 8/8 [00:11<00:00,  1.43s/it, loss=1.23]
# >>> Training epoch 163
# coco_prefix: 100%|█████████████████████| 8/8 [00:11<00:00,  1.41s/it, loss=1.18]
# >>> Training epoch 164
# coco_prefix: 100%|█████████████████████| 8/8 [00:11<00:00,  1.41s/it, loss=1.16]
# >>> Training epoch 165
# coco_prefix: 100%|█████████████████████| 8/8 [00:11<00:00,  1.42s/it, loss=1.21]
# >>> Training epoch 166
# coco_prefix: 100%|██████████████████████| 8/8 [00:11<00:00,  1.41s/it, loss=1.3]
# >>> Training epoch 167
# coco_prefix: 100%|█████████████████████| 8/8 [00:11<00:00,  1.41s/it, loss=1.18]
# >>> Training epoch 168
# coco_prefix: 100%|█████████████████████| 8/8 [00:11<00:00,  1.42s/it, loss=1.22]
# >>> Training epoch 169
# coco_prefix: 100%|█████████████████████| 8/8 [00:11<00:00,  1.41s/it, loss=1.11]
# >>> Training epoch 170
# coco_prefix: 100%|█████████████████████| 8/8 [00:11<00:00,  1.41s/it, loss=1.21]
# >>> Training epoch 171
# coco_prefix: 100%|█████████████████████| 8/8 [00:11<00:00,  1.42s/it, loss=1.13]
# >>> Training epoch 172
# coco_prefix: 100%|█████████████████████| 8/8 [00:11<00:00,  1.42s/it, loss=1.11]
# >>> Training epoch 173
# coco_prefix: 100%|████████████████████| 8/8 [00:11<00:00,  1.41s/it, loss=0.994]
# >>> Training epoch 174
# coco_prefix: 100%|█████████████████████| 8/8 [00:11<00:00,  1.42s/it, loss=1.13]
# >>> Training epoch 175
# coco_prefix: 100%|█████████████████████| 8/8 [00:11<00:00,  1.41s/it, loss=1.16]
# >>> Training epoch 176
# coco_prefix: 100%|█████████████████████| 8/8 [00:11<00:00,  1.41s/it, loss=1.04]
# >>> Training epoch 177
# coco_prefix: 100%|█████████████████████| 8/8 [00:11<00:00,  1.42s/it, loss=1.09]
# >>> Training epoch 178
# coco_prefix: 100%|████████████████████| 8/8 [00:11<00:00,  1.42s/it, loss=0.995]
# >>> Training epoch 179
# coco_prefix: 100%|█████████████████████| 8/8 [00:11<00:00,  1.41s/it, loss=1.09]
# >>> Training epoch 180
# coco_prefix: 100%|█████████████████████| 8/8 [00:11<00:00,  1.42s/it, loss=1.06]
# >>> Training epoch 181
# coco_prefix: 100%|████████████████████| 8/8 [00:11<00:00,  1.41s/it, loss=0.988]
# >>> Training epoch 182
# coco_prefix: 100%|████████████████████| 8/8 [00:11<00:00,  1.41s/it, loss=0.999]
# >>> Training epoch 183
# coco_prefix: 100%|████████████████████| 8/8 [00:11<00:00,  1.42s/it, loss=0.914]
# >>> Training epoch 184
# coco_prefix: 100%|████████████████████| 8/8 [00:11<00:00,  1.41s/it, loss=0.989]
# >>> Training epoch 185
# coco_prefix: 100%|████████████████████| 8/8 [00:11<00:00,  1.41s/it, loss=0.867]
# >>> Training epoch 186
# coco_prefix: 100%|████████████████████| 8/8 [00:11<00:00,  1.42s/it, loss=0.869]
# >>> Training epoch 187
# coco_prefix: 100%|████████████████████| 8/8 [00:11<00:00,  1.41s/it, loss=0.914]
# >>> Training epoch 188
# coco_prefix: 100%|████████████████████| 8/8 [00:11<00:00,  1.41s/it, loss=0.901]
# >>> Training epoch 189
# coco_prefix: 100%|████████████████████| 8/8 [00:11<00:00,  1.42s/it, loss=0.829]
# >>> Training epoch 190
# coco_prefix: 100%|████████████████████| 8/8 [00:11<00:00,  1.41s/it, loss=0.822]
# >>> Training epoch 191
# coco_prefix: 100%|████████████████████| 8/8 [00:11<00:00,  1.41s/it, loss=0.891]
# >>> Training epoch 192
# coco_prefix: 100%|████████████████████| 8/8 [00:11<00:00,  1.42s/it, loss=0.888]
# >>> Training epoch 193
# coco_prefix: 100%|█████████████████████| 8/8 [00:11<00:00,  1.41s/it, loss=0.84]
# >>> Training epoch 194
# coco_prefix: 100%|████████████████████| 8/8 [00:11<00:00,  1.41s/it, loss=0.803]
# >>> Training epoch 195
# coco_prefix: 100%|████████████████████| 8/8 [00:11<00:00,  1.42s/it, loss=0.943]
# >>> Training epoch 196
# coco_prefix: 100%|████████████████████| 8/8 [00:11<00:00,  1.41s/it, loss=0.799]
# >>> Training epoch 197
# coco_prefix: 100%|█████████████████████| 8/8 [00:11<00:00,  1.41s/it, loss=0.76]
# >>> Training epoch 198
# coco_prefix: 100%|████████████████████| 8/8 [00:11<00:00,  1.43s/it, loss=0.865]
# >>> Training epoch 199
# coco_prefix: 100%|████████████████████| 8/8 [00:11<00:00,  1.41s/it, loss=0.787]

# %%
import pandas as pd

# %%
df = pd.read_json('data/coco/annotations/train_caption.json')

# %%
df.head()
# Out:
#    image_id   id                                            caption
# 0    318556   48     A very clean and well decorated empty bathroom
# 1    116100   67  A panoramic view of a kitchen and all of its a...
# 2    318556  126  A blue and white bathroom with butterfly theme...
# 3    116100  148     A panoramic photo of a kitchen and dining room
# 4    379340  173  A graffiti-ed stop sign across the street from...

# %%
df1 = df[0:1000]

# %%
df1.shape
# Out:
# (1000, 3)

# %%
df1.to_json('train_caption.json',orient='records')
